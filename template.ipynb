# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import wandb

# %% [markdown]
# *  Note: Log your training models using Wandb

# %%
# Load MNIST dataset (train, val, test)
# your code

# %%
# Visualize a few images from the training set
# your code

# %%
# Train the model (ResNet, VGG, MobileNet,...)
# your code

# %%
# Evaluate the models with test set
# your code

# %%
# Plotting training and validation accuracy
# your code

# %%
# Discussion test results
